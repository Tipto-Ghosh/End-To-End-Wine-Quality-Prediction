# %% [markdown]
# ## Data Validation Experiment using evidently

# %%
import pandas as pd 
from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab , CatTargetDriftTab
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection

# %%
# load the data
df = pd.read_csv("wine.csv")
df.head()
# Out:
#   wine type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0     white            6.0             0.180  ...       0.58     11.1        8
# 1     white            5.3             0.395  ...       0.35     10.6        6
# 2       red            8.1             0.560  ...       1.28      9.3        5
# 3     white            6.4             0.220  ...       0.70     11.7        6
# 4       red            9.4             0.270  ...       1.13     12.0        7
#
# [5 rows x 13 columns]

# %%
X = df.drop(columns = ['quality'])
y = df['quality']

# %%
from sklearn.model_selection import train_test_split

train_set , test_set = train_test_split(df , test_size = 0.2 , random_state = 42)

# %%
train_set.head()
# Out:
#      wine type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 1916     white            6.1              0.16  ...       0.57     10.3        6
# 947      white            6.9              0.33  ...       0.43     11.2        7
# 877      white            5.6              0.26  ...       0.35     10.2        6
# 2927     white            5.6              0.41  ...       0.40     10.5        5
# 6063     white            7.2              0.13  ...       0.45     11.1        5
#
# [5 rows x 13 columns]

# %%
data_drift_dashboard = Dashboard(tabs = [DataDriftTab()])

# %%
data_drift_dashboard.calculate(reference_data = train_set , current_data = test_set)

# %%
# save as a html file
data_drift_dashboard.save("data_drift_test.html")

# %%
data_drift_profile = Profile(sections = [DataDriftProfileSection()])

# %%
data_drift_profile.calculate(reference_data = train_set , current_data = test_set)

# %%
report = data_drift_profile.json()

# %%
import json
json_report = json.loads(report)
json_report
# Out:
# {'data_drift': {'name': 'data_drift',
#   'datetime': '2025-08-29 14:48:19.769998',
#   'data': {'utility_columns': {'date': None,
#     'id': None,
#     'target': None,
#     'prediction': None},
#    'num_feature_names': ['alcohol',
#     'chlorides',
#     'citric acid',
#     'density',
#     'fixed acidity',
#     'free sulfur dioxide',
#     'pH',
#     'quality',
#     'residual sugar',
#     'sulphates',
#     'total sulfur dioxide',
#     'volatile acidity'],
#    'cat_feature_names': ['wine type'],
#    'text_feature_names': [],
#    'datetime_feature_names': [],
#    'target_names': None,
#    'options': {'confidence': None,
#     'drift_share': 0.5,
#     'nbinsx': 10,
#     'xbins': None},
#    'metrics': {'n_features': 13,
#     'n_drifted_features': 0,
#     'share_drifted_features': 0.0,
#     'dataset_drift': False,
#     'alcohol': {'current_small_hist': {'x': [8.4,
#        8.98,
#        9.56,
#        10.14,
#        10.719999999999999,
#        11.3,
#        11.879999999999999,
#        12.459999999999999,
#        13.04,
#        13.62,
#        14.2],
#       'y': [0.08885941644562334,
#        0.3872679045092838,
#        0.30238726790450926,
#        0.2732095490716189,
#        0.21087533156498606,
#        0.175066312997348,
#        0.12864721485411137,
#        0.1246684350132626,
#        0.022546419098143235,
#        0.010610079575596816]},
#      'ref_small_hist': {'x': [8.0,
#        8.69,
#        9.38,
#        10.07,
#        10.76,
#        11.45,
#        12.14,
#        12.83,
#        13.52,
#        14.21,
#        14.9],
#       'y': [0.008366030569475706,
#        0.25655827079725435,
#        0.37061515422777386,
#        0.2562794031116058,
#        0.24512469568563824,
#        0.14027044588154233,
#        0.1257693262277848,
#        0.037926005248289874,
#        0.008087162883826495,
#        0.00027886768564919023]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.034808957384495645,
#      'drift_detected': False},
#     'chlorides': {'current_small_hist': {'x': [0.012,
#        0.057499999999999996,
#        0.103,
#        0.14850000000000002,
#        0.194,
#        0.2395,
#        0.28500000000000003,
#        0.3305,
#        0.376,
#        0.4215,
#        0.467],
#       'y': [15.604395604395604,
#        5.409974640743872,
#        0.6086221470836852,
#        0.18596787827557065,
#        0.08453085376162302,
#        0.016906170752324583,
#        0.016906170752324604,
#        0.016906170752324604,
#        0.016906170752324604,
#        0.016906170752324583]},
#      'ref_small_hist': {'x': [0.009,
#        0.0692,
#        0.1294,
#        0.1896,
#        0.2498,
#        0.31,
#        0.3702,
#        0.4304,
#        0.4906,
#        0.5508,
#        0.611],
#       'y': [12.868400310171278,
#        3.3209806066239347,
#        0.24611694582294794,
#        0.09269339518007129,
#        0.01917794383035958,
#        0.025570591773812785,
#        0.028766915745539353,
#        0.003196323971726598,
#        0.0,
#        0.00639264794345319]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.0538997650555984,
#      'drift_detected': False},
#     'citric acid': {'current_small_hist': {'x': [0.0,
#        0.1,
#        0.2,
#        0.30000000000000004,
#        0.4,
#        0.5,
#        0.6000000000000001,
#        0.7000000000000001,
#        0.8,
#        0.9,
#        1.0],
#       'y': [0.7769230769230769,
#        0.676923076923077,
#        3.3230769230769215,
#        2.86923076923077,
#        1.5153846153846158,
#        0.49999999999999956,
#        0.17692307692307696,
#        0.1384615384615385,
#        0.0,
#        0.02307692307692308]},
#      'ref_small_hist': {'x': [0.0,
#        0.16599999999999998,
#        0.33199999999999996,
#        0.49799999999999994,
#        0.6639999999999999,
#        0.8299999999999998,
#        0.9959999999999999,
#        1.162,
#        1.3279999999999998,
#        1.4939999999999998,
#        1.66],
#       'y': [0.7059216276303985,
#        2.867734165447629,
#        1.9288236262347835,
#        0.3929514478927834,
#        0.11707403019814495,
#        0.004636595255372074,
#        0.004636595255372074,
#        0.0011591488138430193,
#        0.0,
#        0.0011591488138430178]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.027300334016108194,
#      'drift_detected': False},
#     'density': {'current_small_hist': {'x': [0.98711,
#        0.989429,
#        0.9917480000000001,
#        0.994067,
#        0.996386,
#        0.998705,
#        1.001024,
#        1.003343,
#        1.005662,
#        1.007981,
#        1.0103],
#       'y': [13.26831857232915,
#        73.97087604073147,
#        99.51238929246864,
#        107.14167247155788,
#        106.47825654294142,
#        27.20005307327476,
#        2.9853716787737734,
#        0.3317079643082288,
#        0.0,
#        0.3317079643082288]},
#      'ref_small_hist': {'x': [0.98722,
#        0.992396,
#        0.997572,
#        1.002748,
#        1.007924,
#        1.0131000000000001,
#        1.018276,
#        1.023452,
#        1.028628,
#        1.033804,
#        1.03898],
#       'y': [47.99315025105177,
#        108.9604363949107,
#        35.985568894669335,
#        0.18587587238981698,
#        0.037175174477963396,
#        0.0,
#        0.0,
#        0.0,
#        0.0,
#        0.037175174477963396]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.03650141420558781,
#      'drift_detected': False},
#     'fixed acidity': {'current_small_hist': {'x': [4.4,
#        5.5200000000000005,
#        6.640000000000001,
#        7.76,
#        8.879999999999999,
#        10.0,
#        11.12,
#        12.239999999999998,
#        13.36,
#        14.479999999999999,
#        15.6],
#       'y': [0.033653846153846145,
#        0.279532967032967,
#        0.3750000000000003,
#        0.13049450549450559,
#        0.04120879120879117,
#        0.01785714285714287,
#        0.006181318681318686,
#        0.0041208791208791175,
#        0.002747252747252749,
#        0.0020604395604395588]},
#      'ref_small_hist': {'x': [3.8,
#        5.01,
#        6.220000000000001,
#        7.430000000000001,
#        8.64,
#        9.850000000000001,
#        11.060000000000002,
#        12.27,
#        13.48,
#        14.690000000000001,
#        15.9],
#       'y': [0.007633138635290227,
#        0.14343939685482873,
#        0.41409777096449474,
#        0.17079147696461883,
#        0.04897930624311225,
#        0.023376487070576303,
#        0.011449707952935366,
#        0.0054068065333305725,
#        0.0006360948862741851,
#        0.000636094886274186]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.052948893745781246,
#      'drift_detected': False},
#     'free sulfur dioxide': {'current_small_hist': {'x': [1.0,
#        14.0,
#        27.0,
#        40.0,
#        53.0,
#        66.0,
#        79.0,
#        92.0,
#        105.0,
#        118.0,
#        131.0],
#       'y': [0.013668639053254439,
#        0.020414201183431954,
#        0.021183431952662722,
#        0.01242603550295858,
#        0.006686390532544378,
#        0.0018343195266272189,
#        0.0003550295857988166,
#        0.0002366863905325444,
#        5.91715976331361e-05,
#        5.91715976331361e-05]},
#      'ref_small_hist': {'x': [1.0,
#        29.8,
#        58.6,
#        87.4,
#        116.2,
#        145.0,
#        173.8,
#        202.6,
#        231.4,
#        260.2,
#        289.0],
#       'y': [0.018246370769461014,
#        0.014184198148504478,
#        0.002144666794945802,
#        0.00010021807453017768,
#        3.340602484339256e-05,
#        6.681204968678509e-06,
#        0.0,
#        0.0,
#        0.0,
#        6.681204968678509e-06]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.028446109546661793,
#      'drift_detected': False},
#     'pH': {'current_small_hist': {'x': [2.82,
#        2.923,
#        3.026,
#        3.129,
#        3.2319999999999998,
#        3.335,
#        3.4379999999999997,
#        3.541,
#        3.644,
#        3.747,
#        3.85],
#       'y': [0.21657953696788607,
#        0.6497386109036609,
#        1.9268110530246416,
#        2.7707244212098647,
#        1.9417475728155302,
#        1.3069454817027664,
#        0.6123973114264364,
#        0.17923823749066434,
#        0.08215085884988817,
#        0.022404779686333042]},
#      'ref_small_hist': {'x': [2.72,
#        2.849,
#        2.978,
#        3.107,
#        3.2359999999999998,
#        3.365,
#        3.4939999999999998,
#        3.6229999999999998,
#        3.752,
#        3.881,
#        4.01],
#       'y': [0.020882649948613764,
#        0.39826196687713394,
#        1.4826681463515772,
#        2.496968286712826,
#        1.9853433629717732,
#        0.9650767511966538,
#        0.3132397492292065,
#        0.06861442125973094,
#        0.014916178534724118,
#        0.005966471413889647]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.023140173397016323,
#      'drift_detected': False},
#     'quality': {'current_small_hist': {'x': [3.0,
#        3.6,
#        4.2,
#        4.8,
#        5.4,
#        6.0,
#        6.6,
#        7.2,
#        7.8,
#        8.399999999999999,
#        9.0],
#       'y': [0.0025641025641025637,
#        0.05512820512820512,
#        0.0,
#        0.5333333333333329,
#        0.0,
#        0.7512820512820517,
#        0.27307692307692283,
#        0.0,
#        0.0500000000000001,
#        0.001282051282051279]},
#      'ref_small_hist': {'x': [3.0,
#        3.6,
#        4.2,
#        4.8,
#        5.4,
#        6.0,
#        6.6,
#        7.2,
#        7.8,
#        8.399999999999999,
#        9.0],
#       'y': [0.008979539477903918,
#        0.05548072605990635,
#        0.0,
#        0.5522416778910905,
#        0.0,
#        0.7215701366172796,
#        0.2777243281380281,
#        0.0,
#        0.049387467128471654,
#        0.0012827913539862712]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.029738843696521754,
#      'drift_detected': False},
#     'residual sugar': {'current_small_hist': {'x': [0.8,
#        3.88,
#        6.96,
#        10.040000000000001,
#        13.120000000000001,
#        16.2,
#        19.28,
#        22.360000000000003,
#        25.44,
#        28.52,
#        31.6],
#       'y': [0.17332667332667331,
#        0.049950049950049945,
#        0.036713286713286705,
#        0.03071928071928072,
#        0.021228771228771242,
#        0.009490509490509485,
#        0.0029970029970029953,
#        0.0,
#        0.0,
#        0.00024975024975024964]},
#      'ref_small_hist': {'x': [0.6,
#        7.12,
#        13.64,
#        20.160000000000004,
#        26.680000000000003,
#        33.2,
#        39.720000000000006,
#        46.24,
#        52.760000000000005,
#        59.28000000000001,
#        65.8],
#       'y': [0.10751247475242323,
#        0.0332896161187849,
#        0.012217997405298709,
#        0.00029512071027291585,
#        2.9512071027291583e-05,
#        0.0,
#        0.0,
#        0.0,
#        0.0,
#        2.951207102729163e-05]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.03479685559593881,
#      'drift_detected': False},
#     'sulphates': {'current_small_hist': {'x': [0.27,
#        0.399,
#        0.528,
#        0.657,
#        0.786,
#        0.915,
#        1.044,
#        1.173,
#        1.302,
#        1.431,
#        1.56],
#       'y': [1.1687537268932617,
#        3.482409063804413,
#        2.0155038759689923,
#        0.7036374478234942,
#        0.28622540250447226,
#        0.05963029218843172,
#        0.023852116875372687,
#        0.0,
#        0.005963029218843172,
#        0.005963029218843172]},
#      'ref_small_hist': {'x': [0.22,
#        0.398,
#        0.576,
#        0.754,
#        0.9319999999999999,
#        1.1099999999999999,
#        1.288,
#        1.466,
#        1.644,
#        1.8219999999999998,
#        2.0],
#       'y': [0.8939902666404342,
#        2.9284397005186666,
#        1.3642269848854025,
#        0.33511122449641445,
#        0.06161722514934072,
#        0.021620078999768644,
#        0.005405019749942168,
#        0.003243011849965301,
#        0.0,
#        0.00432401579995373]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.09415601093348445,
#      'drift_detected': False},
#     'total sulfur dioxide': {'current_small_hist': {'x': [8.0,
#        41.6,
#        75.2,
#        108.80000000000001,
#        142.4,
#        176.0,
#        209.60000000000002,
#        243.20000000000002,
#        276.8,
#        310.40000000000003,
#        344.0],
#       'y': [0.003914835164835165,
#        0.003228021978021978,
#        0.005402930402930401,
#        0.0071199633699633716,
#        0.005494505494505496,
#        0.003548534798534796,
#        0.000915750915750916,
#        6.86813186813187e-05,
#        2.289377289377288e-05,
#        4.5787545787545835e-05]},
#      'ref_small_hist': {'x': [6.0,
#        49.4,
#        92.8,
#        136.2,
#        179.6,
#        223.0,
#        266.4,
#        309.8,
#        353.2,
#        396.59999999999997,
#        440.0],
#       'y': [0.003901577390004336,
#        0.0034183138269242535,
#        0.0073420592702808886,
#        0.005315899193880907,
#        0.002496122807468683,
#        0.0005275996697846776,
#        3.103527469321629e-05,
#        0.0,
#        4.433610670459475e-06,
#        4.43361067045947e-06]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.03162675513156332,
#      'drift_detected': False},
#     'volatile acidity': {'current_small_hist': {'x': [0.08,
#        0.196,
#        0.312,
#        0.428,
#        0.5439999999999999,
#        0.6599999999999999,
#        0.7759999999999999,
#        0.8919999999999999,
#        1.008,
#        1.124,
#        1.24],
#       'y': [1.246684350132626,
#        3.8660477453580904,
#        1.6511936339522548,
#        0.7891246684350137,
#        0.5305039787798409,
#        0.3050397877984085,
#        0.15251989389920426,
#        0.026525198938992016,
#        0.03978779840848803,
#        0.013262599469496036]},
#      'ref_small_hist': {'x': [0.08,
#        0.22999999999999998,
#        0.38,
#        0.5299999999999999,
#        0.6799999999999999,
#        0.83,
#        0.9799999999999999,
#        1.1300000000000001,
#        1.28,
#        1.43,
#        1.58],
#       'y': [1.607337566544802,
#        3.0697197100891533,
#        1.0364954140209102,
#        0.6388300942851645,
#        0.2180745301776666,
#        0.06927073311525885,
#        0.021807453017766622,
#        0.001282791353986275,
#        0.00256558270797255,
#        0.001282791353986273]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.048723268753148315,
#      'drift_detected': False},
#     'wine type': {'current_small_hist': {'x': ['red', 'white'],
#       'y': [303, 997]},
#      'ref_small_hist': {'x': ['red', 'white'], 'y': [1296, 3901]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.01346932921910849,
#      'drift_detected': False}}}},
#  'timestamp': '2025-08-29 14:48:33.115552'}

# %%
n_features = json_report["data_drift"]["data"]["metrics"]["n_features"]
n_drifted_features = json_report["data_drift"]["data"]["metrics"]["n_drifted_features"]
data_drift_percentage = (n_drifted_features / n_features) * 100

data_drift_percentage
# Out:
# 0.0

# %%
drift_status = json_report["data_drift"]["data"]["metrics"]["dataset_drift"]
drift_status
# Out:
# False

# %% [markdown]
# ### No Data Drift detected. Now do it in modular way.

# %%
train_set.columns
# Out:
# Index(['wine type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')
