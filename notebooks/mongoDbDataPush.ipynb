# %% [markdown]
# ## Here we will push dataset inside MongoDb Atlas

# %%
import pandas as pd 
from pymongo import MongoClient
import certifi
from  dotenv import load_dotenv

# %%
# load both dataset
white_wine_df = pd.read_csv("winequality-white.csv" , delimiter = ';') 
red_wine_df = pd.read_csv("winequality-red.csv" , delimiter = ";")

# %%
white_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(white_wine_df.shape)
print(red_wine_df.shape)
# Out:
# (4898, 12)
# (1599, 12)

# %%
# add new column named wine type
white_wine_df.insert(0 , column = 'wine type' , value = 'white')
red_wine_df.insert(0 , column = 'wine type' , value = 'red')

# %%
red_wine_df.head()
# Out:
#   wine type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       red            7.4              0.70         0.00             1.9
# 1       red            7.8              0.88         0.00             2.6
# 2       red            7.8              0.76         0.04             2.3
# 3       red           11.2              0.28         0.56             1.9
# 4       red            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# 3       0.58      9.8        6
# 4       0.56      9.4        5

# %%
white_wine_df.head()
# Out:
#   wine type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0              0.27         0.36            20.7
# 1     white            6.3              0.30         0.34             1.6
# 2     white            8.1              0.28         0.40             6.9
# 3     white            7.2              0.23         0.32             8.5
# 4     white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df = pd.concat([white_wine_df , red_wine_df] , axis = 0 , ignore_index = True)
df.sample(5)
# Out:
#      wine type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 987      white            7.4              0.30         0.30            5.20
# 2200     white            6.4              0.24         0.23            7.30
# 2391     white            6.5              0.24         0.29            8.20
# 5319       red            6.6              0.84         0.03            2.30
# 2654     white            6.9              0.40         0.22            5.95
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 987       0.053                 45.0                 163.0  0.99410  3.12
# 2200      0.069                 31.0                 157.0  0.99620  3.25
# 2391      0.043                 32.0                 156.0  0.99453  3.13
# 5319      0.059                 32.0                  48.0  0.99520  3.52
# 2654      0.081                 76.0                 303.0  0.99705  3.40
#
#       sulphates  alcohol  quality
# 987        0.45     10.3        6
# 2200       0.53      9.1        5
# 2391       0.70     10.1        6
# 5319       0.56     12.3        7
# 2654       0.57      9.4        5

# %%
# Shuffle rows
df = df.sample(frac = 1 , random_state = 2).reset_index(drop = True)

# %%
# as mongo expects dict format data so convert dataframe into dict
data = df.to_dict(orient = 'records')

# %%
print(df.shape)
print(len(data))
# Out:
# (6497, 13)
# 6497

# %%
data
# Out:
# [{'wine type': 'white',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.18,
#   'citric acid': 0.31,
#   'residual sugar': 1.4,
#   'chlorides': 0.036,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 75.0,
#   'density': 0.99085,
#   'pH': 3.34,
#   'sulphates': 0.58,
#   'alcohol': 11.1,
#   'quality': 8},
#  {'wine type': 'white',
#   'fixed acidity': 5.3,
#   'volatile acidity': 0.395,
#   'citric acid': 0.07,
#   'residual sugar': 1.3,
#   'chlorides': 0.035,
#   'free sulfur dioxide': 26.0,
#   'total sulfur dioxide': 102.0,
#   'density': 0.992,
#   'pH': 3.5,
#   'sulphates': 0.35,
#   'alcohol': 10.6,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 8.1,
#   'volatile acidity': 0.56,
#   'citric acid': 0.28,
#   'residual sugar': 1.7,
#   'chlorides': 0.368,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 56.0,
#   'density': 0.9968,
#   'pH': 3.11,
#   'sulphates': 1.28,
#   'alcohol': 9.3,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.4,
#   'volatile acidity': 0.22,
#   'citric acid': 0.34,
#   'residual sugar': 1.4,
#   'chlorides': 0.023,
#   'free sulfur dioxide': 56.0,
#   'total sulfur dioxide': 115.0,
#   'density': 0.98958,
#   'pH': 3.18,
#   'sulphates': 0.7,
#   'alcohol': 11.7,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 9.4,
#   'volatile acidity': 0.27,
#   'citric acid': 0.53,
#   'residual sugar': 2.4,
#   'chlorides': 0.074,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 18.0,
#   'density': 0.9962,
#   'pH': 3.2,
#   'sulphates': 1.13,
#   'alcohol': 12.0,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.32,
#   'citric acid': 0.44,
#   'residual sugar': 2.4,
#   'chlorides': 0.061,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 34.0,
#   'density': 0.99484,
#   'pH': 3.29,
#   'sulphates': 0.8,
#   'alcohol': 11.6,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 11.6,
#   'volatile acidity': 0.23,
#   'citric acid': 0.57,
#   'residual sugar': 1.8,
#   'chlorides': 0.074,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 8.0,
#   'density': 0.9981,
#   'pH': 3.14,
#   'sulphates': 0.7,
#   'alcohol': 9.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.9,
#   'volatile acidity': 0.22,
#   'citric acid': 0.3,
#   'residual sugar': 1.3,
#   'chlorides': 0.052,
#   'free sulfur dioxide': 42.0,
#   'total sulfur dioxide': 86.0,
#   'density': 0.99069,
#   'pH': 3.31,
#   'sulphates': 0.47,
#   'alcohol': 11.55,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.9,
#   'volatile acidity': 0.35,
#   'citric acid': 0.46,
#   'residual sugar': 3.6,
#   'chlorides': 0.078,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 37.0,
#   'density': 0.9973,
#   'pH': 3.35,
#   'sulphates': 0.86,
#   'alcohol': 12.8,
#   'quality': 8},
#  {'wine type': 'white',
#   'fixed acidity': 6.3,
#   'volatile acidity': 0.27,
#   'citric acid': 0.23,
#   'residual sugar': 2.9,
#   'chlorides': 0.047,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 100.0,
#   'density': 0.9936,
#   'pH': 3.28,
#   'sulphates': 0.43,
#   'alcohol': 9.8,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.35,
#   'citric acid': 0.48,
#   'residual sugar': 8.8,
#   'chlorides': 0.056,
#   'free sulfur dioxide': 35.0,
#   'total sulfur dioxide': 167.0,
#   'density': 0.99628,
#   'pH': 3.04,
#   'sulphates': 0.47,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.6,
#   'volatile acidity': 0.19,
#   'citric acid': 0.41,
#   'residual sugar': 1.1,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 38.0,
#   'total sulfur dioxide': 143.0,
#   'density': 0.9907,
#   'pH': 2.92,
#   'sulphates': 0.42,
#   'alcohol': 11.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.4,
#   'volatile acidity': 0.28,
#   'citric acid': 0.43,
#   'residual sugar': 7.1,
#   'chlorides': 0.045,
#   'free sulfur dioxide': 60.0,
#   'total sulfur dioxide': 221.0,
#   'density': 0.9952,
#   'pH': 3.09,
#   'sulphates': 0.45,
#   'alcohol': 9.4,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.52,
#   'citric acid': 0.07,
#   'residual sugar': 1.4,
#   'chlorides': 0.074,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9973,
#   'pH': 3.32,
#   'sulphates': 0.81,
#   'alcohol': 9.6,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.28,
#   'citric acid': 0.3,
#   'residual sugar': 1.6,
#   'chlorides': 0.047,
#   'free sulfur dioxide': 46.0,
#   'total sulfur dioxide': 132.0,
#   'density': 0.9918,
#   'pH': 3.35,
#   'sulphates': 0.38,
#   'alcohol': 11.1,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 7.6,
#   'volatile acidity': 0.22,
#   'citric acid': 0.34,
#   'residual sugar': 9.7,
#   'chlorides': 0.035,
#   'free sulfur dioxide': 26.0,
#   'total sulfur dioxide': 143.0,
#   'density': 0.9965,
#   'pH': 3.08,
#   'sulphates': 0.49,
#   'alcohol': 9.8,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.765,
#   'citric acid': 0.18,
#   'residual sugar': 2.4,
#   'chlorides': 0.243,
#   'free sulfur dioxide': 5.5,
#   'total sulfur dioxide': 48.0,
#   'density': 0.99612,
#   'pH': 3.4,
#   'sulphates': 0.6,
#   'alcohol': 10.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.25,
#   'citric acid': 0.28,
#   'residual sugar': 7.7,
#   'chlorides': 0.053,
#   'free sulfur dioxide': 37.0,
#   'total sulfur dioxide': 132.0,
#   'density': 0.99489,
#   'pH': 3.06,
#   'sulphates': 0.5,
#   'alcohol': 9.4,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.43,
#   'citric acid': 0.42,
#   'residual sugar': 5.5,
#   'chlorides': 0.071,
#   'free sulfur dioxide': 28.0,
#   'total sulfur dioxide': 128.0,
#   'density': 0.9973,
#   'pH': 3.42,
#   'sulphates': 0.71,
#   'alcohol': 10.5,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.3,
#   'volatile acidity': 0.27,
#   'citric acid': 0.46,
#   'residual sugar': 11.1,
#   'chlorides': 0.053,
#   'free sulfur dioxide': 44.0,
#   'total sulfur dioxide': 177.0,
#   'density': 0.99691,
#   'pH': 3.18,
#   'sulphates': 0.67,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.5,
#   'citric acid': 0.11,
#   'residual sugar': 1.5,
#   'chlorides': 0.075,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 49.0,
#   'density': 0.99545,
#   'pH': 3.36,
#   'sulphates': 0.79,
#   'alcohol': 9.5,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.26,
#   'citric acid': 0.27,
#   'residual sugar': 4.2,
#   'chlorides': 0.031,
#   'free sulfur dioxide': 20.0,
#   'total sulfur dioxide': 80.0,
#   'density': 0.99089,
#   'pH': 3.12,
#   'sulphates': 0.39,
#   'alcohol': 11.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.28,
#   'citric acid': 0.24,
#   'residual sugar': 17.8,
#   'chlorides': 0.047,
#   'free sulfur dioxide': 42.0,
#   'total sulfur dioxide': 111.0,
#   'density': 0.99896,
#   'pH': 3.1,
#   'sulphates': 0.45,
#   'alcohol': 8.9,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.6,
#   'volatile acidity': 0.42,
#   'citric acid': 0.08,
#   'residual sugar': 2.7,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 48.0,
#   'density': 0.9968,
#   'pH': 3.21,
#   'sulphates': 0.59,
#   'alcohol': 10.0,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 8.0,
#   'volatile acidity': 0.22,
#   'citric acid': 0.32,
#   'residual sugar': 10.4,
#   'chlorides': 0.043,
#   'free sulfur dioxide': 63.0,
#   'total sulfur dioxide': 201.0,
#   'density': 0.997,
#   'pH': 3.11,
#   'sulphates': 0.53,
#   'alcohol': 9.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.3,
#   'citric acid': 0.3,
#   'residual sugar': 1.3,
#   'chlorides': 0.053,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 186.0,
#   'density': 0.99361,
#   'pH': 3.29,
#   'sulphates': 0.54,
#   'alcohol': 9.9,
#   'quality': 4},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.23,
#   'citric acid': 0.32,
#   'residual sugar': 0.9,
#   'chlorides': 0.041,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 79.0,
#   'density': 0.9926,
#   'pH': 3.39,
#   'sulphates': 0.54,
#   'alcohol': 10.2,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 5.7,
#   'volatile acidity': 0.21,
#   'citric acid': 0.37,
#   'residual sugar': 4.5,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 58.0,
#   'total sulfur dioxide': 140.0,
#   'density': 0.99332,
#   'pH': 3.29,
#   'sulphates': 0.62,
#   'alcohol': 10.6,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 8.0,
#   'volatile acidity': 0.77,
#   'citric acid': 0.32,
#   'residual sugar': 2.1,
#   'chlorides': 0.079,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 74.0,
#   'density': 0.99656,
#   'pH': 3.27,
#   'sulphates': 0.5,
#   'alcohol': 9.8,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.41,
#   'citric acid': 0.3,
#   'residual sugar': 2.1,
#   'chlorides': 0.083,
#   'free sulfur dioxide': 35.0,
#   'total sulfur dioxide': 72.0,
#   'density': 0.997,
#   'pH': 3.44,
#   'sulphates': 0.52,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 10.4,
#   'volatile acidity': 0.43,
#   'citric acid': 0.5,
#   'residual sugar': 2.3,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 19.0,
#   'density': 0.996,
#   'pH': 3.1,
#   'sulphates': 0.87,
#   'alcohol': 11.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.33,
#   'citric acid': 0.31,
#   'residual sugar': 4.2,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 93.0,
#   'density': 0.9896,
#   'pH': 3.18,
#   'sulphates': 0.48,
#   'alcohol': 13.4,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 7.7,
#   'volatile acidity': 0.23,
#   'citric acid': 0.31,
#   'residual sugar': 10.7,
#   'chlorides': 0.038,
#   'free sulfur dioxide': 59.0,
#   'total sulfur dioxide': 186.0,
#   'density': 0.9969,
#   'pH': 3.12,
#   'sulphates': 0.55,
#   'alcohol': 9.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.8,
#   'volatile acidity': 0.32,
#   'citric acid': 0.23,
#   'residual sugar': 1.5,
#   'chlorides': 0.033,
#   'free sulfur dioxide': 39.0,
#   'total sulfur dioxide': 121.0,
#   'density': 0.9887,
#   'pH': 2.96,
#   'sulphates': 0.35,
#   'alcohol': 12.0,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 9.6,
#   'volatile acidity': 0.29,
#   'citric acid': 0.46,
#   'residual sugar': 1.45,
#   'chlorides': 0.039,
#   'free sulfur dioxide': 77.5,
#   'total sulfur dioxide': 223.0,
#   'density': 0.9944,
#   'pH': 2.92,
#   'sulphates': 0.46,
#   'alcohol': 9.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.54,
#   'citric acid': 0.32,
#   'residual sugar': 13.2,
#   'chlorides': 0.05,
#   'free sulfur dioxide': 53.0,
#   'total sulfur dioxide': 236.0,
#   'density': 0.9973,
#   'pH': 3.2,
#   'sulphates': 0.5,
#   'alcohol': 9.6,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.4,
#   'citric acid': 0.49,
#   'residual sugar': 1.1,
#   'chlorides': 0.048,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 138.0,
#   'density': 0.9929,
#   'pH': 3.01,
#   'sulphates': 0.42,
#   'alcohol': 9.3,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.0,
#   'volatile acidity': 0.27,
#   'citric acid': 0.32,
#   'residual sugar': 6.8,
#   'chlorides': 0.047,
#   'free sulfur dioxide': 47.0,
#   'total sulfur dioxide': 193.0,
#   'density': 0.9938,
#   'pH': 3.23,
#   'sulphates': 0.39,
#   'alcohol': 11.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.19,
#   'citric acid': 0.43,
#   'residual sugar': 10.9,
#   'chlorides': 0.045,
#   'free sulfur dioxide': 53.0,
#   'total sulfur dioxide': 154.0,
#   'density': 0.99752,
#   'pH': 3.52,
#   'sulphates': 0.77,
#   'alcohol': 10.4,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 9.1,
#   'volatile acidity': 0.22,
#   'citric acid': 0.24,
#   'residual sugar': 2.1,
#   'chlorides': 0.078,
#   'free sulfur dioxide': 1.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.999,
#   'pH': 3.41,
#   'sulphates': 0.87,
#   'alcohol': 10.3,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 9.5,
#   'volatile acidity': 0.57,
#   'citric acid': 0.27,
#   'residual sugar': 2.3,
#   'chlorides': 0.082,
#   'free sulfur dioxide': 23.0,
#   'total sulfur dioxide': 144.0,
#   'density': 0.99782,
#   'pH': 3.27,
#   'sulphates': 0.55,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.3,
#   'volatile acidity': 0.23,
#   'citric acid': 0.24,
#   'residual sugar': 0.9,
#   'chlorides': 0.031,
#   'free sulfur dioxide': 29.0,
#   'total sulfur dioxide': 86.0,
#   'density': 0.98926,
#   'pH': 2.9,
#   'sulphates': 0.38,
#   'alcohol': 12.2,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.33,
#   'citric acid': 0.33,
#   'residual sugar': 1.7,
#   'chlorides': 0.061,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 13.0,
#   'density': 0.996,
#   'pH': 3.23,
#   'sulphates': 1.1,
#   'alcohol': 10.0,
#   'quality': 8},
#  {'wine type': 'red',
#   'fixed acidity': 8.1,
#   'volatile acidity': 0.73,
#   'citric acid': 0.0,
#   'residual sugar': 2.5,
#   'chlorides': 0.081,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 24.0,
#   'density': 0.99798,
#   'pH': 3.38,
#   'sulphates': 0.46,
#   'alcohol': 9.6,
#   'quality': 4},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.3,
#   'citric acid': 0.29,
#   'residual sugar': 2.25,
#   'chlorides': 0.037,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 210.0,
#   'density': 0.9937,
#   'pH': 3.19,
#   'sulphates': 0.62,
#   'alcohol': 9.9,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.49,
#   'citric acid': 0.0,
#   'residual sugar': 2.3,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 33.0,
#   'density': 0.99292,
#   'pH': 3.58,
#   'sulphates': 0.59,
#   'alcohol': 12.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.24,
#   'citric acid': 0.41,
#   'residual sugar': 9.4,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 49.0,
#   'total sulfur dioxide': 166.0,
#   'density': 0.9954,
#   'pH': 3.12,
#   'sulphates': 0.61,
#   'alcohol': 9.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.0,
#   'volatile acidity': 0.35,
#   'citric acid': 0.3,
#   'residual sugar': 6.5,
#   'chlorides': 0.028,
#   'free sulfur dioxide': 27.0,
#   'total sulfur dioxide': 87.0,
#   'density': 0.9936,
#   'pH': 3.4,
#   'sulphates': 0.42,
#   'alcohol': 11.4,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 9.5,
#   'volatile acidity': 0.56,
#   'citric acid': 0.33,
#   'residual sugar': 2.4,
#   'chlorides': 0.089,
#   'free sulfur dioxide': 35.0,
#   'total sulfur dioxide': 67.0,
#   'density': 0.9972,
#   'pH': 3.28,
#   'sulphates': 0.73,
#   'alcohol': 11.8,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 10.9,
#   'volatile acidity': 0.39,
#   'citric acid': 0.47,
#   'residual sugar': 1.8,
#   'chlorides': 0.118,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 14.0,
#   'density': 0.9982,
#   'pH': 3.3,
#   'sulphates': 0.75,
#   'alcohol': 9.8,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.43,
#   'citric acid': 0.23,
#   'residual sugar': 5.0,
#   'chlorides': 0.157,
#   'free sulfur dioxide': 49.0,
#   'total sulfur dioxide': 145.0,
#   'density': 0.99471,
#   'pH': 3.17,
#   'sulphates': 0.49,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.7,
#   'volatile acidity': 0.35,
#   'citric acid': 0.49,
#   'residual sugar': 8.65,
#   'chlorides': 0.033,
#   'free sulfur dioxide': 42.0,
#   'total sulfur dioxide': 186.0,
#   'density': 0.9931,
#   'pH': 3.14,
#   'sulphates': 0.38,
#   'alcohol': 12.4,
#   'quality': 8},
#  {'wine type': 'white',
#   'fixed acidity': 7.7,
#   'volatile acidity': 0.15,
#   'citric acid': 0.29,
#   'residual sugar': 1.3,
#   'chlorides': 0.029,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 64.0,
#   'density': 0.9932,
#   'pH': 3.35,
#   'sulphates': 0.39,
#   'alcohol': 10.1,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 7.3,
#   'volatile acidity': 1.07,
#   'citric acid': 0.09,
#   'residual sugar': 1.7,
#   'chlorides': 0.178,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 89.0,
#   'density': 0.9962,
#   'pH': 3.3,
#   'sulphates': 0.57,
#   'alcohol': 9.0,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.36,
#   'citric acid': 0.16,
#   'residual sugar': 1.3,
#   'chlorides': 0.054,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 107.0,
#   'density': 0.99398,
#   'pH': 3.19,
#   'sulphates': 0.39,
#   'alcohol': 8.5,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.725,
#   'citric acid': 0.05,
#   'residual sugar': 4.65,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 11.0,
#   'density': 0.9962,
#   'pH': 3.41,
#   'sulphates': 0.39,
#   'alcohol': 10.9,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.48,
#   'citric acid': 0.08,
#   'residual sugar': 1.8,
#   'chlorides': 0.074,
#   'free sulfur dioxide': 40.0,
#   'total sulfur dioxide': 64.0,
#   'density': 0.99529,
#   'pH': 3.12,
#   'sulphates': 0.49,
#   'alcohol': 9.6,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.26,
#   'citric acid': 0.21,
#   'residual sugar': 2.9,
#   'chlorides': 0.026,
#   'free sulfur dioxide': 48.0,
#   'total sulfur dioxide': 126.0,
#   'density': 0.99089,
#   'pH': 3.22,
#   'sulphates': 0.38,
#   'alcohol': 11.3,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.33,
#   'citric acid': 0.49,
#   'residual sugar': 1.6,
#   'chlorides': 0.167,
#   'free sulfur dioxide': 20.0,
#   'total sulfur dioxide': 94.0,
#   'density': 0.9914,
#   'pH': 3.11,
#   'sulphates': 0.5,
#   'alcohol': 11.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.7,
#   'volatile acidity': 0.3,
#   'citric acid': 0.34,
#   'residual sugar': 1.2,
#   'chlorides': 0.048,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 119.0,
#   'density': 0.99084,
#   'pH': 3.18,
#   'sulphates': 0.34,
#   'alcohol': 12.1,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.0,
#   'volatile acidity': 0.35,
#   'citric acid': 0.25,
#   'residual sugar': 7.8,
#   'chlorides': 0.031,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 116.0,
#   'density': 0.99241,
#   'pH': 3.39,
#   'sulphates': 0.4,
#   'alcohol': 11.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.0,
#   'volatile acidity': 0.24,
#   'citric acid': 0.3,
#   'residual sugar': 4.2,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 41.0,
#   'total sulfur dioxide': 213.0,
#   'density': 0.9927,
#   'pH': 3.28,
#   'sulphates': 0.49,
#   'alcohol': 11.8,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.21,
#   'citric acid': 0.36,
#   'residual sugar': 15.7,
#   'chlorides': 0.045,
#   'free sulfur dioxide': 68.0,
#   'total sulfur dioxide': 183.0,
#   'density': 0.99922,
#   'pH': 3.25,
#   'sulphates': 0.76,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.64,
#   'citric acid': 0.0,
#   'residual sugar': 2.7,
#   'chlorides': 0.123,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 33.0,
#   'density': 0.99538,
#   'pH': 3.44,
#   'sulphates': 0.63,
#   'alcohol': 11.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.3,
#   'volatile acidity': 0.23,
#   'citric acid': 0.33,
#   'residual sugar': 6.9,
#   'chlorides': 0.052,
#   'free sulfur dioxide': 23.0,
#   'total sulfur dioxide': 118.0,
#   'density': 0.9938,
#   'pH': 3.23,
#   'sulphates': 0.46,
#   'alcohol': 10.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.21,
#   'citric acid': 0.35,
#   'residual sugar': 2.5,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 41.0,
#   'total sulfur dioxide': 186.0,
#   'density': 0.99128,
#   'pH': 3.32,
#   'sulphates': 0.56,
#   'alcohol': 12.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.8,
#   'volatile acidity': 0.21,
#   'citric acid': 0.34,
#   'residual sugar': 11.9,
#   'chlorides': 0.039,
#   'free sulfur dioxide': 55.0,
#   'total sulfur dioxide': 140.0,
#   'density': 0.9959,
#   'pH': 3.02,
#   'sulphates': 0.31,
#   'alcohol': 10.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.5,
#   'citric acid': 0.0,
#   'residual sugar': 0.8,
#   'chlorides': 0.034,
#   'free sulfur dioxide': 46.0,
#   'total sulfur dioxide': 114.0,
#   'density': 0.9932,
#   'pH': 3.19,
#   'sulphates': 0.34,
#   'alcohol': 9.2,
#   'quality': 4},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.22,
#   'citric acid': 0.35,
#   'residual sugar': 1.4,
#   'chlorides': 0.05,
#   'free sulfur dioxide': 23.0,
#   'total sulfur dioxide': 83.0,
#   'density': 0.99019,
#   'pH': 3.17,
#   'sulphates': 0.48,
#   'alcohol': 12.0,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 8.8,
#   'volatile acidity': 0.23,
#   'citric acid': 0.35,
#   'residual sugar': 10.7,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 26.0,
#   'total sulfur dioxide': 183.0,
#   'density': 0.9984,
#   'pH': 2.93,
#   'sulphates': 0.49,
#   'alcohol': 9.1,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.3,
#   'volatile acidity': 0.255,
#   'citric acid': 0.37,
#   'residual sugar': 1.1,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 37.0,
#   'total sulfur dioxide': 114.0,
#   'density': 0.9905,
#   'pH': 3.0,
#   'sulphates': 0.39,
#   'alcohol': 10.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.18,
#   'citric acid': 0.28,
#   'residual sugar': 9.8,
#   'chlorides': 0.039,
#   'free sulfur dioxide': 29.0,
#   'total sulfur dioxide': 113.0,
#   'density': 0.99406,
#   'pH': 3.11,
#   'sulphates': 0.45,
#   'alcohol': 10.9,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.59,
#   'citric acid': 0.06,
#   'residual sugar': 6.0,
#   'chlorides': 0.06,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 18.0,
#   'density': 0.9962,
#   'pH': 3.41,
#   'sulphates': 0.59,
#   'alcohol': 10.8,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.18,
#   'citric acid': 0.39,
#   'residual sugar': 14.5,
#   'chlorides': 0.051,
#   'free sulfur dioxide': 48.0,
#   'total sulfur dioxide': 156.0,
#   'density': 0.99947,
#   'pH': 3.35,
#   'sulphates': 0.78,
#   'alcohol': 9.1,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.23,
#   'citric acid': 0.39,
#   'residual sugar': 2.5,
#   'chlorides': 0.172,
#   'free sulfur dioxide': 63.0,
#   'total sulfur dioxide': 158.0,
#   'density': 0.9937,
#   'pH': 3.11,
#   'sulphates': 0.36,
#   'alcohol': 9.4,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 8.9,
#   'volatile acidity': 0.4,
#   'citric acid': 0.51,
#   'residual sugar': 2.6,
#   'chlorides': 0.052,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 27.0,
#   'density': 0.995,
#   'pH': 3.32,
#   'sulphates': 0.9,
#   'alcohol': 13.4,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 7.5,
#   'volatile acidity': 0.16,
#   'citric acid': 0.38,
#   'residual sugar': 12.7,
#   'chlorides': 0.043,
#   'free sulfur dioxide': 70.5,
#   'total sulfur dioxide': 163.0,
#   'density': 0.99706,
#   'pH': 3.15,
#   'sulphates': 0.82,
#   'alcohol': 10.4,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 8.1,
#   'volatile acidity': 0.22,
#   'citric acid': 0.28,
#   'residual sugar': 7.7,
#   'chlorides': 0.043,
#   'free sulfur dioxide': 57.0,
#   'total sulfur dioxide': 176.0,
#   'density': 0.9954,
#   'pH': 3.12,
#   'sulphates': 0.55,
#   'alcohol': 10.0,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.1,
#   'volatile acidity': 0.22,
#   'citric acid': 0.5,
#   'residual sugar': 6.6,
#   'chlorides': 0.045,
#   'free sulfur dioxide': 30.0,
#   'total sulfur dioxide': 122.0,
#   'density': 0.99415,
#   'pH': 3.22,
#   'sulphates': 0.49,
#   'alcohol': 9.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.63,
#   'citric acid': 0.04,
#   'residual sugar': 1.3,
#   'chlorides': 0.058,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 133.0,
#   'density': 0.99271,
#   'pH': 3.17,
#   'sulphates': 0.39,
#   'alcohol': 10.2,
#   'quality': 4},
#  {'wine type': 'red',
#   'fixed acidity': 12.4,
#   'volatile acidity': 0.49,
#   'citric acid': 0.58,
#   'residual sugar': 3.0,
#   'chlorides': 0.103,
#   'free sulfur dioxide': 28.0,
#   'total sulfur dioxide': 99.0,
#   'density': 1.0008,
#   'pH': 3.16,
#   'sulphates': 1.0,
#   'alcohol': 11.5,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.0,
#   'volatile acidity': 0.57,
#   'citric acid': 0.0,
#   'residual sugar': 2.0,
#   'chlorides': 0.19,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 45.0,
#   'density': 0.99676,
#   'pH': 3.31,
#   'sulphates': 0.6,
#   'alcohol': 9.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.1,
#   'volatile acidity': 0.28,
#   'citric acid': 0.16,
#   'residual sugar': 1.3,
#   'chlorides': 0.06,
#   'free sulfur dioxide': 36.0,
#   'total sulfur dioxide': 126.0,
#   'density': 0.99353,
#   'pH': 3.13,
#   'sulphates': 0.46,
#   'alcohol': 8.7,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.6,
#   'citric acid': 0.18,
#   'residual sugar': 1.9,
#   'chlorides': 0.079,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 86.0,
#   'density': 0.9968,
#   'pH': 3.59,
#   'sulphates': 0.57,
#   'alcohol': 9.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.3,
#   'volatile acidity': 0.34,
#   'citric acid': 0.3,
#   'residual sugar': 9.4,
#   'chlorides': 0.057,
#   'free sulfur dioxide': 34.0,
#   'total sulfur dioxide': 178.0,
#   'density': 0.99554,
#   'pH': 3.15,
#   'sulphates': 0.44,
#   'alcohol': 10.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.23,
#   'citric acid': 0.34,
#   'residual sugar': 2.7,
#   'chlorides': 0.032,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 121.0,
#   'density': 0.9902,
#   'pH': 3.14,
#   'sulphates': 0.38,
#   'alcohol': 12.4,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.2,
#   'citric acid': 0.24,
#   'residual sugar': 9.2,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 150.0,
#   'density': 0.99502,
#   'pH': 3.22,
#   'sulphates': 0.44,
#   'alcohol': 10.5,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.6,
#   'volatile acidity': 0.21,
#   'citric acid': 0.44,
#   'residual sugar': 1.9,
#   'chlorides': 0.036,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 119.0,
#   'density': 0.9913,
#   'pH': 3.01,
#   'sulphates': 0.7,
#   'alcohol': 12.8,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.17,
#   'citric acid': 0.38,
#   'residual sugar': 1.5,
#   'chlorides': 0.032,
#   'free sulfur dioxide': 28.0,
#   'total sulfur dioxide': 112.0,
#   'density': 0.9914,
#   'pH': 3.25,
#   'sulphates': 0.55,
#   'alcohol': 11.4,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.25,
#   'citric acid': 0.3,
#   'residual sugar': 1.6,
#   'chlorides': 0.046,
#   'free sulfur dioxide': 32.0,
#   'total sulfur dioxide': 134.0,
#   'density': 0.993,
#   'pH': 3.42,
#   'sulphates': 0.51,
#   'alcohol': 10.1,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 8.1,
#   'volatile acidity': 0.26,
#   'citric acid': 0.37,
#   'residual sugar': 1.9,
#   'chlorides': 0.072,
#   'free sulfur dioxide': 48.0,
#   'total sulfur dioxide': 159.0,
#   'density': 0.9949,
#   'pH': 3.37,
#   'sulphates': 0.7,
#   'alcohol': 10.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.4,
#   'volatile acidity': 0.26,
#   'citric acid': 0.21,
#   'residual sugar': 7.1,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 35.0,
#   'total sulfur dioxide': 162.0,
#   'density': 0.9956,
#   'pH': 3.39,
#   'sulphates': 0.58,
#   'alcohol': 9.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.5,
#   'volatile acidity': 0.23,
#   'citric acid': 0.32,
#   'residual sugar': 9.2,
#   'chlorides': 0.038,
#   'free sulfur dioxide': 54.0,
#   'total sulfur dioxide': 191.0,
#   'density': 0.9966,
#   'pH': 3.04,
#   'sulphates': 0.56,
#   'alcohol': 9.7,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.48,
#   'citric acid': 0.28,
#   'residual sugar': 2.8,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 16.0,
#   'density': 0.99682,
#   'pH': 3.24,
#   'sulphates': 0.53,
#   'alcohol': 10.3,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 5.7,
#   'volatile acidity': 0.265,
#   'citric acid': 0.28,
#   'residual sugar': 6.9,
#   'chlorides': 0.036,
#   'free sulfur dioxide': 46.0,
#   'total sulfur dioxide': 150.0,
#   'density': 0.99299,
#   'pH': 3.36,
#   'sulphates': 0.44,
#   'alcohol': 10.8,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.4,
#   'volatile acidity': 0.26,
#   'citric acid': 0.25,
#   'residual sugar': 10.7,
#   'chlorides': 0.046,
#   'free sulfur dioxide': 66.0,
#   'total sulfur dioxide': 179.0,
#   'density': 0.99606,
#   'pH': 3.17,
#   'sulphates': 0.55,
#   'alcohol': 9.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.9,
#   'volatile acidity': 0.18,
#   'citric acid': 0.49,
#   'residual sugar': 5.2,
#   'chlorides': 0.051,
#   'free sulfur dioxide': 36.0,
#   'total sulfur dioxide': 157.0,
#   'density': 0.9953,
#   'pH': 3.18,
#   'sulphates': 0.48,
#   'alcohol': 10.6,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.15,
#   'citric acid': 0.32,
#   'residual sugar': 7.9,
#   'chlorides': 0.034,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 81.0,
#   'density': 0.99512,
#   'pH': 3.29,
#   'sulphates': 0.31,
#   'alcohol': 10.0,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.28,
#   'citric acid': 0.14,
#   'residual sugar': 1.4,
#   'chlorides': 0.043,
#   'free sulfur dioxide': 64.0,
#   'total sulfur dioxide': 159.0,
#   'density': 0.992,
#   'pH': 3.17,
#   'sulphates': 0.39,
#   'alcohol': 10.0,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 12.0,
#   'volatile acidity': 0.38,
#   'citric acid': 0.56,
#   'residual sugar': 2.1,
#   'chlorides': 0.093,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 24.0,
#   'density': 0.99925,
#   'pH': 3.14,
#   'sulphates': 0.71,
#   'alcohol': 10.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 8.0,
#   'volatile acidity': 0.34,
#   'citric acid': 0.49,
#   'residual sugar': 9.0,
#   'chlorides': 0.033,
#   'free sulfur dioxide': 39.0,
#   'total sulfur dioxide': 180.0,
#   'density': 0.9936,
#   'pH': 3.13,
#   'sulphates': 0.38,
#   'alcohol': 12.3,
#   'quality': 8},
#  {'wine type': 'white',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.27,
#   'citric acid': 0.24,
#   'residual sugar': 12.6,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 48.0,
#   'total sulfur dioxide': 118.0,
#   'density': 0.99726,
#   'pH': 3.04,
#   'sulphates': 0.56,
#   'alcohol': 10.0,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.34,
#   'citric acid': 0.3,
#   'residual sugar': 8.4,
#   'chlorides': 0.051,
#   'free sulfur dioxide': 40.0,
#   'total sulfur dioxide': 167.0,
#   'density': 0.99756,
#   'pH': 3.48,
#   'sulphates': 0.62,
#   'alcohol': 9.7,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 5.8,
#   'volatile acidity': 0.19,
#   'citric acid': 0.49,
#   'residual sugar': 4.9,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 44.0,
#   'total sulfur dioxide': 118.0,
#   'density': 0.9935,
#   'pH': 3.34,
#   'sulphates': 0.38,
#   'alcohol': 9.5,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.49,
#   'citric acid': 0.22,
#   'residual sugar': 2.3,
#   'chlorides': 0.071,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 24.0,
#   'density': 0.99438,
#   'pH': 3.41,
#   'sulphates': 0.83,
#   'alcohol': 11.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.22,
#   'citric acid': 0.34,
#   'residual sugar': 12.0,
#   'chlorides': 0.053,
#   'free sulfur dioxide': 55.0,
#   'total sulfur dioxide': 177.0,
#   'density': 0.9983,
#   'pH': 3.52,
#   'sulphates': 0.44,
#   'alcohol': 9.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.37,
#   'citric acid': 0.23,
#   'residual sugar': 9.5,
#   'chlorides': 0.057,
#   'free sulfur dioxide': 54.0,
#   'total sulfur dioxide': 166.0,
#   'density': 0.99568,
#   'pH': 3.23,
#   'sulphates': 0.42,
#   'alcohol': 10.0,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.25,
#   'citric acid': 0.32,
#   'residual sugar': 9.9,
#   'chlorides': 0.045,
#   'free sulfur dioxide': 41.0,
#   'total sulfur dioxide': 128.0,
#   'density': 0.99636,
#   'pH': 3.18,
#   'sulphates': 0.52,
#   'alcohol': 9.6,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.23,
#   'citric acid': 0.38,
#   'residual sugar': 6.1,
#   'chlorides': 0.067,
#   'free sulfur dioxide': 20.0,
#   'total sulfur dioxide': 90.0,
#   'density': 0.99496,
#   'pH': 3.17,
#   'sulphates': 0.79,
#   'alcohol': 9.7,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.16,
#   'citric acid': 0.64,
#   'residual sugar': 2.1,
#   'chlorides': 0.059,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 52.0,
#   'density': 0.99494,
#   'pH': 3.34,
#   'sulphates': 0.71,
#   'alcohol': 11.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.14,
#   'citric acid': 0.35,
#   'residual sugar': 1.5,
#   'chlorides': 0.047,
#   'free sulfur dioxide': 40.0,
#   'total sulfur dioxide': 117.0,
#   'density': 0.99111,
#   'pH': 3.07,
#   'sulphates': 0.72,
#   'alcohol': 11.1,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.3,
#   'volatile acidity': 0.23,
#   'citric acid': 0.27,
#   'residual sugar': 2.6,
#   'chlorides': 0.035,
#   'free sulfur dioxide': 39.0,
#   'total sulfur dioxide': 120.0,
#   'density': 0.99138,
#   'pH': 3.04,
#   'sulphates': 0.59,
#   'alcohol': 11.3,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.13,
#   'citric acid': 0.28,
#   'residual sugar': 1.2,
#   'chlorides': 0.046,
#   'free sulfur dioxide': 35.0,
#   'total sulfur dioxide': 140.0,
#   'density': 0.9927,
#   'pH': 3.33,
#   'sulphates': 0.33,
#   'alcohol': 10.1,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 8.5,
#   'volatile acidity': 0.28,
#   'citric acid': 0.35,
#   'residual sugar': 1.7,
#   'chlorides': 0.061,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 15.0,
#   'density': 0.99524,
#   'pH': 3.3,
#   'sulphates': 0.74,
#   'alcohol': 11.8,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.41,
#   'citric acid': 0.22,
#   'residual sugar': 4.2,
#   'chlorides': 0.031,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 102.0,
#   'density': 0.993,
#   'pH': 3.0,
#   'sulphates': 0.86,
#   'alcohol': 11.6,
#   'quality': 4},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.67,
#   'citric acid': 0.15,
#   'residual sugar': 1.8,
#   'chlorides': 0.118,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9954,
#   'pH': 3.42,
#   'sulphates': 0.67,
#   'alcohol': 11.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.9,
#   'volatile acidity': 0.18,
#   'citric acid': 0.28,
#   'residual sugar': 1.0,
#   'chlorides': 0.037,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 88.0,
#   'density': 0.99094,
#   'pH': 3.29,
#   'sulphates': 0.55,
#   'alcohol': 10.65,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 7.3,
#   'volatile acidity': 0.43,
#   'citric acid': 0.37,
#   'residual sugar': 4.6,
#   'chlorides': 0.028,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 114.0,
#   'density': 0.991,
#   'pH': 3.23,
#   'sulphates': 0.43,
#   'alcohol': 13.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.1,
#   'volatile acidity': 0.23,
#   'citric acid': 0.27,
#   'residual sugar': 9.8,
#   'chlorides': 0.055,
#   'free sulfur dioxide': 74.0,
#   'total sulfur dioxide': 134.0,
#   'density': 0.99534,
#   'pH': 3.16,
#   'sulphates': 0.4,
#   'alcohol': 10.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.4,
#   'volatile acidity': 0.35,
#   'citric acid': 0.2,
#   'residual sugar': 13.9,
#   'chlorides': 0.054,
#   'free sulfur dioxide': 63.0,
#   'total sulfur dioxide': 229.0,
#   'density': 0.99888,
#   'pH': 3.11,
#   'sulphates': 0.5,
#   'alcohol': 8.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.4,
#   'volatile acidity': 0.24,
#   'citric acid': 0.22,
#   'residual sugar': 1.5,
#   'chlorides': 0.038,
#   'free sulfur dioxide': 38.0,
#   'total sulfur dioxide': 157.0,
#   'density': 0.9934,
#   'pH': 3.41,
#   'sulphates': 0.55,
#   'alcohol': 9.9,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.51,
#   'citric acid': 0.01,
#   'residual sugar': 2.1,
#   'chlorides': 0.074,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 25.0,
#   'density': 0.9958,
#   'pH': 3.33,
#   'sulphates': 0.56,
#   'alcohol': 9.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.8,
#   'volatile acidity': 0.28,
#   'citric acid': 0.34,
#   'residual sugar': 2.2,
#   'chlorides': 0.037,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 125.0,
#   'density': 0.98986,
#   'pH': 3.36,
#   'sulphates': 0.33,
#   'alcohol': 12.8,
#   'quality': 8},
#  {'wine type': 'white',
#   'fixed acidity': 6.2,
#   'volatile acidity': 0.39,
#   'citric acid': 0.24,
#   'residual sugar': 4.8,
#   'chlorides': 0.037,
#   'free sulfur dioxide': 45.0,
#   'total sulfur dioxide': 138.0,
#   'density': 0.99174,
#   'pH': 3.23,
#   'sulphates': 0.43,
#   'alcohol': 11.2,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 5.7,
#   'volatile acidity': 0.28,
#   'citric acid': 0.3,
#   'residual sugar': 3.9,
#   'chlorides': 0.026,
#   'free sulfur dioxide': 36.0,
#   'total sulfur dioxide': 105.0,
#   'density': 0.98963,
#   'pH': 3.26,
#   'sulphates': 0.58,
#   'alcohol': 12.75,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.6,
#   'volatile acidity': 0.19,
#   'citric acid': 0.26,
#   'residual sugar': 1.4,
#   'chlorides': 0.03,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 76.0,
#   'density': 0.9905,
#   'pH': 3.25,
#   'sulphates': 0.37,
#   'alcohol': 10.9,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 7.3,
#   'volatile acidity': 0.43,
#   'citric acid': 0.24,
#   'residual sugar': 2.5,
#   'chlorides': 0.078,
#   'free sulfur dioxide': 27.0,
#   'total sulfur dioxide': 67.0,
#   'density': 0.99648,
#   'pH': 3.6,
#   'sulphates': 0.59,
#   'alcohol': 11.1,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.17,
#   'citric acid': 0.74,
#   'residual sugar': 2.4,
#   'chlorides': 0.053,
#   'free sulfur dioxide': 61.0,
#   'total sulfur dioxide': 182.0,
#   'density': 0.9953,
#   'pH': 3.63,
#   'sulphates': 0.76,
#   'alcohol': 10.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.8,
#   'volatile acidity': 0.28,
#   'citric acid': 0.32,
#   'residual sugar': 9.0,
#   'chlorides': 0.036,
#   'free sulfur dioxide': 34.0,
#   'total sulfur dioxide': 115.0,
#   'density': 0.9952,
#   'pH': 3.17,
#   'sulphates': 0.39,
#   'alcohol': 10.3,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.3,
#   'volatile acidity': 0.18,
#   'citric acid': 0.22,
#   'residual sugar': 5.6,
#   'chlorides': 0.047,
#   'free sulfur dioxide': 45.0,
#   'total sulfur dioxide': 147.0,
#   'density': 0.99383,
#   'pH': 3.09,
#   'sulphates': 0.54,
#   'alcohol': 10.0,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 8.3,
#   'volatile acidity': 0.26,
#   'citric acid': 0.31,
#   'residual sugar': 2.0,
#   'chlorides': 0.029,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 141.0,
#   'density': 0.99077,
#   'pH': 2.95,
#   'sulphates': 0.77,
#   'alcohol': 12.2,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 10.0,
#   'volatile acidity': 0.42,
#   'citric acid': 0.5,
#   'residual sugar': 3.4,
#   'chlorides': 0.107,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 21.0,
#   'density': 0.9979,
#   'pH': 3.26,
#   'sulphates': 0.93,
#   'alcohol': 11.8,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.26,
#   'citric acid': 0.56,
#   'residual sugar': 11.9,
#   'chlorides': 0.043,
#   'free sulfur dioxide': 64.0,
#   'total sulfur dioxide': 226.0,
#   'density': 0.997,
#   'pH': 3.02,
#   'sulphates': 0.63,
#   'alcohol': 9.3,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 11.4,
#   'volatile acidity': 0.625,
#   'citric acid': 0.66,
#   'residual sugar': 6.2,
#   'chlorides': 0.088,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 24.0,
#   'density': 0.9988,
#   'pH': 3.11,
#   'sulphates': 0.99,
#   'alcohol': 13.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.26,
#   'citric acid': 0.74,
#   'residual sugar': 13.6,
#   'chlorides': 0.05,
#   'free sulfur dioxide': 56.0,
#   'total sulfur dioxide': 162.0,
#   'density': 0.998,
#   'pH': 3.03,
#   'sulphates': 0.44,
#   'alcohol': 8.8,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.8,
#   'volatile acidity': 0.25,
#   'citric acid': 0.37,
#   'residual sugar': 1.0,
#   'chlorides': 0.043,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 80.0,
#   'density': 0.99128,
#   'pH': 3.08,
#   'sulphates': 0.38,
#   'alcohol': 11.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.0,
#   'volatile acidity': 0.28,
#   'citric acid': 0.39,
#   'residual sugar': 8.7,
#   'chlorides': 0.051,
#   'free sulfur dioxide': 32.0,
#   'total sulfur dioxide': 141.0,
#   'density': 0.9961,
#   'pH': 3.38,
#   'sulphates': 0.53,
#   'alcohol': 10.5,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.52,
#   'citric acid': 0.07,
#   'residual sugar': 1.4,
#   'chlorides': 0.074,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9973,
#   'pH': 3.32,
#   'sulphates': 0.81,
#   'alcohol': 9.6,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.22,
#   'citric acid': 0.53,
#   'residual sugar': 15.1,
#   'chlorides': 0.052,
#   'free sulfur dioxide': 22.0,
#   'total sulfur dioxide': 136.0,
#   'density': 0.9986,
#   'pH': 2.94,
#   'sulphates': 0.35,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.59,
#   'citric acid': 0.02,
#   'residual sugar': 2.3,
#   'chlorides': 0.082,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 94.0,
#   'density': 0.99744,
#   'pH': 3.55,
#   'sulphates': 0.53,
#   'alcohol': 9.7,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.0,
#   'volatile acidity': 0.21,
#   'citric acid': 0.34,
#   'residual sugar': 8.0,
#   'chlorides': 0.057,
#   'free sulfur dioxide': 19.0,
#   'total sulfur dioxide': 101.0,
#   'density': 0.9954,
#   'pH': 2.99,
#   'sulphates': 0.59,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 12.2,
#   'volatile acidity': 0.45,
#   'citric acid': 0.49,
#   'residual sugar': 1.4,
#   'chlorides': 0.075,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 6.0,
#   'density': 0.9969,
#   'pH': 3.13,
#   'sulphates': 0.63,
#   'alcohol': 10.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.9,
#   'volatile acidity': 0.19,
#   'citric acid': 0.26,
#   'residual sugar': 2.1,
#   'chlorides': 0.039,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 143.0,
#   'density': 0.9942,
#   'pH': 3.05,
#   'sulphates': 0.74,
#   'alcohol': 9.8,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.3,
#   'citric acid': 0.26,
#   'residual sugar': 1.5,
#   'chlorides': 0.041,
#   'free sulfur dioxide': 46.0,
#   'total sulfur dioxide': 178.0,
#   'density': 0.99154,
#   'pH': 3.19,
#   'sulphates': 0.56,
#   'alcohol': 11.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 8.3,
#   'volatile acidity': 0.24,
#   'citric acid': 0.27,
#   'residual sugar': 2.1,
#   'chlorides': 0.03,
#   'free sulfur dioxide': 22.0,
#   'total sulfur dioxide': 162.0,
#   'density': 0.9914,
#   'pH': 2.99,
#   'sulphates': 0.68,
#   'alcohol': 11.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.28,
#   'citric acid': 0.42,
#   'residual sugar': 3.5,
#   'chlorides': 0.035,
#   'free sulfur dioxide': 43.0,
#   'total sulfur dioxide': 105.0,
#   'density': 0.99021,
#   'pH': 3.18,
#   'sulphates': 0.38,
#   'alcohol': 12.2,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.4,
#   'volatile acidity': 0.64,
#   'citric acid': 0.17,
#   'residual sugar': 5.4,
#   'chlorides': 0.168,
#   'free sulfur dioxide': 52.0,
#   'total sulfur dioxide': 98.0,
#   'density': 0.99736,
#   'pH': 3.28,
#   'sulphates': 0.5,
#   'alcohol': 9.5,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.26,
#   'citric acid': 0.26,
#   'residual sugar': 2.0,
#   'chlorides': 0.019,
#   'free sulfur dioxide': 23.5,
#   'total sulfur dioxide': 72.0,
#   'density': 0.99041,
#   'pH': 3.16,
#   'sulphates': 0.47,
#   'alcohol': 11.8,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.15,
#   'volatile acidity': 0.17,
#   'citric acid': 0.24,
#   'residual sugar': 9.6,
#   'chlorides': 0.119,
#   'free sulfur dioxide': 56.0,
#   'total sulfur dioxide': 178.0,
#   'density': 0.99578,
#   'pH': 3.15,
#   'sulphates': 0.44,
#   'alcohol': 10.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.6,
#   'volatile acidity': 0.12,
#   'citric acid': 0.33,
#   'residual sugar': 2.9,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 73.0,
#   'density': 0.98896,
#   'pH': 3.17,
#   'sulphates': 0.32,
#   'alcohol': 12.9,
#   'quality': 8},
#  {'wine type': 'red',
#   'fixed acidity': 9.3,
#   'volatile acidity': 0.43,
#   'citric acid': 0.44,
#   'residual sugar': 1.9,
#   'chlorides': 0.085,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 22.0,
#   'density': 0.99708,
#   'pH': 3.28,
#   'sulphates': 0.55,
#   'alcohol': 9.5,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 9.2,
#   'volatile acidity': 0.63,
#   'citric acid': 0.21,
#   'residual sugar': 2.7,
#   'chlorides': 0.097,
#   'free sulfur dioxide': 29.0,
#   'total sulfur dioxide': 65.0,
#   'density': 0.9988,
#   'pH': 3.28,
#   'sulphates': 0.58,
#   'alcohol': 9.6,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.9,
#   'volatile acidity': 0.22,
#   'citric acid': 0.45,
#   'residual sugar': 14.2,
#   'chlorides': 0.038,
#   'free sulfur dioxide': 53.0,
#   'total sulfur dioxide': 141.0,
#   'density': 0.9992,
#   'pH': 3.03,
#   'sulphates': 0.46,
#   'alcohol': 9.2,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 11.9,
#   'volatile acidity': 0.38,
#   'citric acid': 0.51,
#   'residual sugar': 2.0,
#   'chlorides': 0.121,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9996,
#   'pH': 3.24,
#   'sulphates': 0.76,
#   'alcohol': 10.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.2,
#   'volatile acidity': 0.3,
#   'citric acid': 0.2,
#   'residual sugar': 6.6,
#   'chlorides': 0.045,
#   'free sulfur dioxide': 42.0,
#   'total sulfur dioxide': 170.0,
#   'density': 0.9944,
#   'pH': 3.36,
#   'sulphates': 0.45,
#   'alcohol': 10.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.2,
#   'volatile acidity': 0.26,
#   'citric acid': 0.19,
#   'residual sugar': 3.4,
#   'chlorides': 0.049,
#   'free sulfur dioxide': 47.0,
#   'total sulfur dioxide': 172.0,
#   'density': 0.9924,
#   'pH': 3.14,
#   'sulphates': 0.43,
#   'alcohol': 10.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.43,
#   'citric acid': 0.24,
#   'residual sugar': 11.9,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 54.0,
#   'total sulfur dioxide': 159.0,
#   'density': 0.99622,
#   'pH': 3.14,
#   'sulphates': 0.54,
#   'alcohol': 9.8,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.41,
#   'citric acid': 0.05,
#   'residual sugar': 1.5,
#   'chlorides': 0.063,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 120.0,
#   'density': 0.9932,
#   'pH': 3.21,
#   'sulphates': 0.56,
#   'alcohol': 9.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.3,
#   'volatile acidity': 0.17,
#   'citric acid': 0.32,
#   'residual sugar': 4.2,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 37.0,
#   'total sulfur dioxide': 117.0,
#   'density': 0.99182,
#   'pH': 3.24,
#   'sulphates': 0.43,
#   'alcohol': 11.3,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 6.8,
#   'volatile acidity': 0.68,
#   'citric acid': 0.09,
#   'residual sugar': 3.9,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 15.0,
# ...
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.9,
#   'volatile acidity': 0.33,
#   'citric acid': 0.26,
#   'residual sugar': 5.0,
#   'chlorides': 0.027,
#   'free sulfur dioxide': 46.0,
#   'total sulfur dioxide': 143.0,
#   'density': 0.9924,
#   'pH': 3.25,
#   'sulphates': 0.43,
#   'alcohol': 11.2,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.21,
#   'citric acid': 0.4,
#   'residual sugar': 7.3,
#   'chlorides': 0.041,
#   'free sulfur dioxide': 49.0,
#   'total sulfur dioxide': 115.0,
#   'density': 0.99268,
#   'pH': 3.21,
#   'sulphates': 0.43,
#   'alcohol': 11.0,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.31,
#   'citric acid': 0.26,
#   'residual sugar': 7.3,
#   'chlorides': 0.05,
#   'free sulfur dioxide': 37.0,
#   'total sulfur dioxide': 157.0,
#   'density': 0.99625,
#   'pH': 3.09,
#   'sulphates': 0.43,
#   'alcohol': 9.0,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.39,
#   'citric acid': 0.35,
#   'residual sugar': 12.5,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 26.0,
#   'total sulfur dioxide': 72.0,
#   'density': 0.9941,
#   'pH': 3.17,
#   'sulphates': 0.29,
#   'alcohol': 11.6,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.5,
#   'volatile acidity': 0.27,
#   'citric acid': 0.79,
#   'residual sugar': 11.95,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 51.0,
#   'total sulfur dioxide': 159.0,
#   'density': 0.99839,
#   'pH': 2.98,
#   'sulphates': 0.44,
#   'alcohol': 8.7,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.21,
#   'citric acid': 0.29,
#   'residual sugar': 13.1,
#   'chlorides': 0.042,
#   'free sulfur dioxide': 28.0,
#   'total sulfur dioxide': 125.0,
#   'density': 0.99936,
#   'pH': 3.39,
#   'sulphates': 0.45,
#   'alcohol': 8.6,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.33,
#   'citric acid': 0.28,
#   'residual sugar': 6.1,
#   'chlorides': 0.018,
#   'free sulfur dioxide': 41.0,
#   'total sulfur dioxide': 103.0,
#   'density': 0.99122,
#   'pH': 3.24,
#   'sulphates': 0.32,
#   'alcohol': 12.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.35,
#   'citric acid': 0.51,
#   'residual sugar': 1.2,
#   'chlorides': 0.029,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 102.0,
#   'density': 0.9903,
#   'pH': 3.46,
#   'sulphates': 0.42,
#   'alcohol': 11.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.8,
#   'volatile acidity': 0.27,
#   'citric acid': 0.27,
#   'residual sugar': 12.3,
#   'chlorides': 0.045,
#   'free sulfur dioxide': 55.0,
#   'total sulfur dioxide': 170.0,
#   'density': 0.9972,
#   'pH': 3.28,
#   'sulphates': 0.42,
#   'alcohol': 9.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.64,
#   'citric acid': 0.28,
#   'residual sugar': 4.4,
#   'chlorides': 0.032,
#   'free sulfur dioxide': 19.0,
#   'total sulfur dioxide': 78.0,
#   'density': 0.99036,
#   'pH': 3.11,
#   'sulphates': 0.62,
#   'alcohol': 12.9,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.8,
#   'volatile acidity': 0.82,
#   'citric acid': 0.29,
#   'residual sugar': 4.3,
#   'chlorides': 0.083,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 64.0,
#   'density': 0.99642,
#   'pH': 3.16,
#   'sulphates': 0.53,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 8.7,
#   'volatile acidity': 0.31,
#   'citric acid': 0.73,
#   'residual sugar': 14.35,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 27.0,
#   'total sulfur dioxide': 191.0,
#   'density': 1.00013,
#   'pH': 2.96,
#   'sulphates': 0.88,
#   'alcohol': 8.7,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.5,
#   'volatile acidity': 0.17,
#   'citric acid': 0.71,
#   'residual sugar': 11.8,
#   'chlorides': 0.038,
#   'free sulfur dioxide': 52.0,
#   'total sulfur dioxide': 148.0,
#   'density': 0.99801,
#   'pH': 3.03,
#   'sulphates': 0.46,
#   'alcohol': 8.9,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 6.2,
#   'volatile acidity': 0.3,
#   'citric acid': 0.21,
#   'residual sugar': 1.1,
#   'chlorides': 0.032,
#   'free sulfur dioxide': 31.0,
#   'total sulfur dioxide': 111.0,
#   'density': 0.9889,
#   'pH': 2.97,
#   'sulphates': 0.42,
#   'alcohol': 12.2,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 7.4,
#   'volatile acidity': 0.58,
#   'citric acid': 0.0,
#   'residual sugar': 2.0,
#   'chlorides': 0.064,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 11.0,
#   'density': 0.99562,
#   'pH': 3.45,
#   'sulphates': 0.58,
#   'alcohol': 11.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.27,
#   'citric acid': 0.31,
#   'residual sugar': 5.0,
#   'chlorides': 0.043,
#   'free sulfur dioxide': 54.0,
#   'total sulfur dioxide': 170.0,
#   'density': 0.9924,
#   'pH': 3.28,
#   'sulphates': 0.52,
#   'alcohol': 11.0,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.8,
#   'volatile acidity': 0.3,
#   'citric acid': 0.12,
#   'residual sugar': 1.6,
#   'chlorides': 0.036,
#   'free sulfur dioxide': 57.0,
#   'total sulfur dioxide': 163.0,
#   'density': 0.99239,
#   'pH': 3.38,
#   'sulphates': 0.59,
#   'alcohol': 10.5,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.3,
#   'volatile acidity': 0.145,
#   'citric acid': 0.33,
#   'residual sugar': 1.1,
#   'chlorides': 0.042,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 64.0,
#   'density': 0.99012,
#   'pH': 3.1,
#   'sulphates': 0.37,
#   'alcohol': 11.8,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.39,
#   'citric acid': 0.35,
#   'residual sugar': 1.6,
#   'chlorides': 0.049,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 164.0,
#   'density': 0.99516,
#   'pH': 3.35,
#   'sulphates': 0.51,
#   'alcohol': 9.7,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 8.5,
#   'volatile acidity': 0.24,
#   'citric acid': 0.39,
#   'residual sugar': 10.4,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 20.0,
#   'total sulfur dioxide': 142.0,
#   'density': 0.9974,
#   'pH': 3.2,
#   'sulphates': 0.53,
#   'alcohol': 10.0,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.6,
#   'volatile acidity': 0.24,
#   'citric acid': 0.27,
#   'residual sugar': 15.8,
#   'chlorides': 0.035,
#   'free sulfur dioxide': 46.0,
#   'total sulfur dioxide': 188.0,
#   'density': 0.9982,
#   'pH': 3.24,
#   'sulphates': 0.51,
#   'alcohol': 9.2,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.4,
#   'volatile acidity': 0.16,
#   'citric acid': 0.49,
#   'residual sugar': 1.2,
#   'chlorides': 0.055,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 150.0,
#   'density': 0.9917,
#   'pH': 3.23,
#   'sulphates': 0.47,
#   'alcohol': 11.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.5,
#   'volatile acidity': 0.21,
#   'citric acid': 0.32,
#   'residual sugar': 4.8,
#   'chlorides': 0.056,
#   'free sulfur dioxide': 39.0,
#   'total sulfur dioxide': 113.0,
#   'density': 0.99393,
#   'pH': 3.11,
#   'sulphates': 0.52,
#   'alcohol': 10.2,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 6.7,
#   'volatile acidity': 0.38,
#   'citric acid': 0.26,
#   'residual sugar': 9.55,
#   'chlorides': 0.036,
#   'free sulfur dioxide': 35.0,
#   'total sulfur dioxide': 91.0,
#   'density': 0.9919,
#   'pH': 2.98,
#   'sulphates': 0.37,
#   'alcohol': 12.4,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 8.2,
#   'volatile acidity': 0.32,
#   'citric acid': 0.42,
#   'residual sugar': 2.3,
#   'chlorides': 0.098,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 9.0,
#   'density': 0.99506,
#   'pH': 3.27,
#   'sulphates': 0.55,
#   'alcohol': 12.3,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.8,
#   'volatile acidity': 0.445,
#   'citric acid': 0.56,
#   'residual sugar': 1.0,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 84.0,
#   'density': 0.9938,
#   'pH': 3.25,
#   'sulphates': 0.43,
#   'alcohol': 10.8,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 9.1,
#   'volatile acidity': 0.37,
#   'citric acid': 0.32,
#   'residual sugar': 2.1,
#   'chlorides': 0.064,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 15.0,
#   'density': 0.99576,
#   'pH': 3.3,
#   'sulphates': 0.8,
#   'alcohol': 11.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.1,
#   'volatile acidity': 0.26,
#   'citric acid': 0.33,
#   'residual sugar': 1.1,
#   'chlorides': 0.027,
#   'free sulfur dioxide': 46.0,
#   'total sulfur dioxide': 113.0,
#   'density': 0.98946,
#   'pH': 3.35,
#   'sulphates': 0.43,
#   'alcohol': 11.4,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.18,
#   'citric acid': 0.39,
#   'residual sugar': 15.25,
#   'chlorides': 0.047,
#   'free sulfur dioxide': 45.0,
#   'total sulfur dioxide': 158.0,
#   'density': 0.99946,
#   'pH': 3.34,
#   'sulphates': 0.77,
#   'alcohol': 9.1,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.41,
#   'citric acid': 0.22,
#   'residual sugar': 4.8,
#   'chlorides': 0.052,
#   'free sulfur dioxide': 49.0,
#   'total sulfur dioxide': 142.0,
#   'density': 0.9946,
#   'pH': 3.14,
#   'sulphates': 0.62,
#   'alcohol': 9.2,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 7.6,
#   'volatile acidity': 0.54,
#   'citric acid': 0.02,
#   'residual sugar': 1.7,
#   'chlorides': 0.085,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.99589,
#   'pH': 3.37,
#   'sulphates': 0.51,
#   'alcohol': 10.4,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 9.8,
#   'volatile acidity': 0.93,
#   'citric acid': 0.45,
#   'residual sugar': 8.6,
#   'chlorides': 0.052,
#   'free sulfur dioxide': 34.0,
#   'total sulfur dioxide': 187.0,
#   'density': 0.9994,
#   'pH': 3.12,
#   'sulphates': 0.59,
#   'alcohol': 10.2,
#   'quality': 4},
#  {'wine type': 'white',
#   'fixed acidity': 6.2,
#   'volatile acidity': 0.35,
#   'citric acid': 0.29,
#   'residual sugar': 7.3,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 56.0,
#   'total sulfur dioxide': 244.0,
#   'density': 0.9956,
#   'pH': 3.36,
#   'sulphates': 0.55,
#   'alcohol': 10.0,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.5,
#   'volatile acidity': 0.27,
#   'citric acid': 0.4,
#   'residual sugar': 10.0,
#   'chlorides': 0.039,
#   'free sulfur dioxide': 74.0,
#   'total sulfur dioxide': 227.0,
#   'density': 0.99582,
#   'pH': 3.18,
#   'sulphates': 0.5,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 5.7,
#   'volatile acidity': 0.31,
#   'citric acid': 0.29,
#   'residual sugar': 7.3,
#   'chlorides': 0.05,
#   'free sulfur dioxide': 33.0,
#   'total sulfur dioxide': 143.0,
#   'density': 0.99332,
#   'pH': 3.31,
#   'sulphates': 0.5,
#   'alcohol': 11.0666666666667,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.4,
#   'volatile acidity': 0.29,
#   'citric acid': 0.18,
#   'residual sugar': 15.0,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 116.0,
#   'density': 0.99736,
#   'pH': 3.14,
#   'sulphates': 0.5,
#   'alcohol': 9.2,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 7.6,
#   'volatile acidity': 0.38,
#   'citric acid': 0.28,
#   'residual sugar': 4.2,
#   'chlorides': 0.029,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 112.0,
#   'density': 0.9906,
#   'pH': 3.0,
#   'sulphates': 0.41,
#   'alcohol': 12.6,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.1,
#   'volatile acidity': 0.37,
#   'citric acid': 0.3,
#   'residual sugar': 6.2,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 49.0,
#   'total sulfur dioxide': 139.0,
#   'density': 0.99021,
#   'pH': 3.17,
#   'sulphates': 0.27,
#   'alcohol': 13.6,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.3,
#   'volatile acidity': 0.23,
#   'citric acid': 0.33,
#   'residual sugar': 1.5,
#   'chlorides': 0.036,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 105.0,
#   'density': 0.991,
#   'pH': 3.32,
#   'sulphates': 0.42,
#   'alcohol': 11.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 6.0,
#   'volatile acidity': 0.31,
#   'citric acid': 0.38,
#   'residual sugar': 4.8,
#   'chlorides': 0.04,
#   'free sulfur dioxide': 41.0,
#   'total sulfur dioxide': 101.0,
#   'density': 0.98968,
#   'pH': 3.24,
#   'sulphates': 0.56,
#   'alcohol': 13.1,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.7,
#   'volatile acidity': 0.22,
#   'citric acid': 0.22,
#   'residual sugar': 16.65,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 39.0,
#   'total sulfur dioxide': 110.0,
#   'density': 0.99855,
#   'pH': 3.24,
#   'sulphates': 0.48,
#   'alcohol': 9.0,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.0,
#   'volatile acidity': 0.19,
#   'citric acid': 0.33,
#   'residual sugar': 6.3,
#   'chlorides': 0.032,
#   'free sulfur dioxide': 42.0,
#   'total sulfur dioxide': 127.0,
#   'density': 0.99182,
#   'pH': 3.31,
#   'sulphates': 0.38,
#   'alcohol': 12.2,
#   'quality': 6},
#  {'wine type': 'red',
#   'fixed acidity': 6.2,
#   'volatile acidity': 0.7,
#   'citric acid': 0.15,
#   'residual sugar': 5.1,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 27.0,
#   'density': 0.99622,
#   'pH': 3.54,
#   'sulphates': 0.6,
#   'alcohol': 11.9,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.5,
#   'volatile acidity': 0.22,
#   'citric acid': 0.29,
#   'residual sugar': 4.8,
#   'chlorides': 0.05,
#   'free sulfur dioxide': 33.0,
#   'total sulfur dioxide': 87.0,
#   'density': 0.994,
#   'pH': 3.14,
#   'sulphates': 0.42,
#   'alcohol': 9.9,
#   'quality': 5},
#  {'wine type': 'red',
#   'fixed acidity': 7.2,
#   'volatile acidity': 0.49,
#   'citric acid': 0.18,
#   'residual sugar': 2.7,
#   'chlorides': 0.069,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 34.0,
#   'density': 0.9967,
#   'pH': 3.29,
#   'sulphates': 0.48,
#   'alcohol': 9.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.9,
#   'volatile acidity': 0.29,
#   'citric acid': 0.16,
#   'residual sugar': 7.9,
#   'chlorides': 0.044,
#   'free sulfur dioxide': 48.0,
#   'total sulfur dioxide': 197.0,
#   'density': 0.99512,
#   'pH': 3.21,
#   'sulphates': 0.36,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'wine type': 'white',
#   'fixed acidity': 5.4,
#   'volatile acidity': 0.46,
#   'citric acid': 0.15,
#   'residual sugar': 2.1,
#   'chlorides': 0.026,
#   'free sulfur dioxide': 29.0,
#   'total sulfur dioxide': 130.0,
#   'density': 0.98953,
#   'pH': 3.39,
#   'sulphates': 0.77,
#   'alcohol': 13.4,
#   'quality': 8},
#  {'wine type': 'white',
#   'fixed acidity': 7.4,
#   'volatile acidity': 0.19,
#   'citric acid': 0.3,
#   'residual sugar': 1.4,
#   'chlorides': 0.057,
#   'free sulfur dioxide': 33.0,
#   'total sulfur dioxide': 135.0,
#   'density': 0.993,
#   'pH': 3.12,
#   'sulphates': 0.5,
#   'alcohol': 9.6,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 7.0,
#   'volatile acidity': 0.46,
#   'citric acid': 0.39,
#   'residual sugar': 6.2,
#   'chlorides': 0.039,
#   'free sulfur dioxide': 46.0,
#   'total sulfur dioxide': 163.0,
#   'density': 0.9928,
#   'pH': 3.21,
#   'sulphates': 0.35,
#   'alcohol': 12.2,
#   'quality': 7},
#  {'wine type': 'white',
#   'fixed acidity': 7.4,
#   'volatile acidity': 0.16,
#   'citric acid': 0.49,
#   'residual sugar': 1.2,
#   'chlorides': 0.055,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 150.0,
#   'density': 0.9917,
#   'pH': 3.23,
#   'sulphates': 0.47,
#   'alcohol': 11.2,
#   'quality': 6},
#  {'wine type': 'white',
#   'fixed acidity': 5.8,
#   'volatile acidity': 0.36,
#   'citric acid': 0.38,
#   'residual sugar': 0.9,
#   'chlorides': 0.037,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 75.0,
#   'density': 0.9904,
#   'pH': 3.28,
#   'sulphates': 0.34,
#   'alcohol': 11.4,
#   'quality': 4},
#  {'wine type': 'white',
#   'fixed acidity': 7.4,
#   'volatile acidity': 0.19,
#   'citric acid': 0.3,
#   'residual sugar': 12.8,
#   'chlorides': 0.053,
#   'free sulfur dioxide': 48.5,
#   'total sulfur dioxide': 212.0,
#   'density': 0.9986,
#   'pH': 3.14,
#   'sulphates': 0.49,
#   'alcohol': 9.1,
#   'quality': 7},
#  {'wine type': 'red',
#   'fixed acidity': 7.4,
#   'volatile acidity': 0.59,
#   'citric acid': 0.08,
#   'residual sugar': 4.4,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 29.0,
#   'density': 0.9974,
#   'pH': 3.38,
#   'sulphates': 0.5,
#   'alcohol': 9.0,
#   'quality': 4},
#  ...]

# %% [markdown]
# ### steps to push data into mongoDb
# - connect with the cluster
# - create a database
# - create a collection
# - insert the data into mongo

# %%
import os 
load_dotenv()
DATABASE_URL = os.getenv("DATABASE_URL") # load from .env file
DATABASE_NAME = "wineData"
COLLECTION_NAME = "wineCollection"

# %%
import certifi
# connect to the database
client = MongoClient(DATABASE_URL , tlsCAFile = certifi.where())

# %%
type(client)
# Out:
# pymongo.synchronous.mongo_client.MongoClient

# %%
# create the database
database = client[DATABASE_NAME]
# create the collection
collection = database[COLLECTION_NAME]

# %%
# now insert the data into the collection
records = collection.insert_many(data)

# %%
records
# Out:
# InsertManyResult([ObjectId('68afcc53c87d04415342d4fb'), ObjectId('68afcc53c87d04415342d4fc'), ObjectId('68afcc53c87d04415342d4fd'), ObjectId('68afcc53c87d04415342d4fe'), ObjectId('68afcc53c87d04415342d4ff'), ObjectId('68afcc53c87d04415342d500'), ObjectId('68afcc53c87d04415342d501'), ObjectId('68afcc53c87d04415342d502'), ObjectId('68afcc53c87d04415342d503'), ObjectId('68afcc53c87d04415342d504'), ObjectId('68afcc53c87d04415342d505'), ObjectId('68afcc53c87d04415342d506'), ObjectId('68afcc53c87d04415342d507'), ObjectId('68afcc53c87d04415342d508'), ObjectId('68afcc53c87d04415342d509'), ObjectId('68afcc53c87d04415342d50a'), ObjectId('68afcc53c87d04415342d50b'), ObjectId('68afcc53c87d04415342d50c'), ObjectId('68afcc53c87d04415342d50d'), ObjectId('68afcc53c87d04415342d50e'), ObjectId('68afcc53c87d04415342d50f'), ObjectId('68afcc53c87d04415342d510'), ObjectId('68afcc53c87d04415342d511'), ObjectId('68afcc53c87d04415342d512'), ObjectId('68afcc53c87d04415342d513'), ObjectId('68afcc53c87d04415342d514'), ObjectId('68afcc53c87d04415342d515'), ObjectId('68afcc53c87d04415342d516'), ObjectId('68afcc53c87d04415342d517'), ObjectId('68afcc53c87d04415342d518'), ObjectId('68afcc53c87d04415342d519'), ObjectId('68afcc53c87d04415342d51a'), ObjectId('68afcc53c87d04415342d51b'), ObjectId('68afcc53c87d04415342d51c'), ObjectId('68afcc53c87d04415342d51d'), ObjectId('68afcc53c87d04415342d51e'), ObjectId('68afcc53c87d04415342d51f'), ObjectId('68afcc53c87d04415342d520'), ObjectId('68afcc53c87d04415342d521'), ObjectId('68afcc53c87d04415342d522'), ObjectId('68afcc53c87d04415342d523'), ObjectId('68afcc53c87d04415342d524'), ObjectId('68afcc53c87d04415342d525'), ObjectId('68afcc53c87d04415342d526'), ObjectId('68afcc53c87d04415342d527'), ObjectId('68afcc53c87d04415342d528'), ObjectId('68afcc53c87d04415342d529'), ObjectId('68afcc53c87d04415342d52a'), ObjectId('68afcc53c87d04415342d52b'), ObjectId('68afcc53c87d04415342d52c'), ObjectId('68afcc53c87d04415342d52d'), ObjectId('68afcc53c87d04415342d52e'), ObjectId('68afcc53c87d04415342d52f'), ObjectId('68afcc53c87d04415342d530'), ObjectId('68afcc53c87d04415342d531'), ObjectId('68afcc53c87d04415342d532'), ObjectId('68afcc53c87d04415342d533'), ObjectId('68afcc53c87d04415342d534'), ObjectId('68afcc53c87d04415342d535'), ObjectId('68afcc53c87d04415342d536'), ObjectId('68afcc53c87d04415342d537'), ObjectId('68afcc53c87d04415342d538'), ObjectId('68afcc53c87d04415342d539'), ObjectId('68afcc53c87d04415342d53a'), ObjectId('68afcc53c87d04415342d53b'), ObjectId('68afcc53c87d04415342d53c'), ObjectId('68afcc53c87d04415342d53d'), ObjectId('68afcc53c87d04415342d53e'), ObjectId('68afcc53c87d04415342d53f'), ObjectId('68afcc53c87d04415342d540'), ObjectId('68afcc53c87d04415342d541'), ObjectId('68afcc53c87d04415342d542'), ObjectId('68afcc53c87d04415342d543'), ObjectId('68afcc53c87d04415342d544'), ObjectId('68afcc53c87d04415342d545'), ObjectId('68afcc53c87d04415342d546'), ObjectId('68afcc53c87d04415342d547'), ObjectId('68afcc53c87d04415342d548'), ObjectId('68afcc53c87d04415342d549'), ObjectId('68afcc53c87d04415342d54a'), ObjectId('68afcc53c87d04415342d54b'), ObjectId('68afcc53c87d04415342d54c'), ObjectId('68afcc53c87d04415342d54d'), ObjectId('68afcc53c87d04415342d54e'), ObjectId('68afcc53c87d04415342d54f'), ObjectId('68afcc53c87d04415342d550'), ObjectId('68afcc53c87d04415342d551'), ObjectId('68afcc53c87d04415342d552'), ObjectId('68afcc53c87d04415342d553'), ObjectId('68afcc53c87d04415342d554'), ObjectId('68afcc53c87d04415342d555'), ObjectId('68afcc53c87d04415342d556'), ObjectId('68afcc53c87d04415342d557'), ObjectId('68afcc53c87d04415342d558'), ObjectId('68afcc53c87d04415342d559'), ObjectId('68afcc53c87d04415342d55a'), ObjectId('68afcc53c87d04415342d55b'), ObjectId('68afcc53c87d04415342d55c'), ObjectId('68afcc53c87d04415342d55d'), ObjectId('68afcc53c87d04415342d55e'), ObjectId('68afcc53c87d04415342d55f'), ObjectId('68afcc53c87d04415342d560'), ObjectId('68afcc53c87d04415342d561'), ObjectId('68afcc53c87d04415342d562'), ObjectId('68afcc53c87d04415342 ...

# %%
# get all data from the database(checking data pushed have any issue or not)
data_list = list(collection.find())
len(data_list)
# Out:
# 6497

# %%
test_df = pd.DataFrame(data_list)
test_df.head()
# Out:
#                         _id wine type  fixed acidity  volatile acidity  \
# 0  68afcc53c87d04415342d4fb     white            6.0             0.180
# 1  68afcc53c87d04415342d4fc     white            5.3             0.395
# 2  68afcc53c87d04415342d4fd       red            8.1             0.560
# 3  68afcc53c87d04415342d4fe     white            6.4             0.220
# 4  68afcc53c87d04415342d4ff       red            9.4             0.270
#
#    citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0         0.31             1.4      0.036                 14.0
# 1         0.07             1.3      0.035                 26.0
# 2         0.28             1.7      0.368                 16.0
# 3         0.34             1.4      0.023                 56.0
# 4         0.53             2.4      0.074                  6.0
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                  75.0  0.99085  3.34       0.58     11.1        8
# 1                 102.0  0.99200  3.50       0.35     10.6        6
# 2                  56.0  0.99680  3.11       1.28      9.3        5
# 3                 115.0  0.98958  3.18       0.70     11.7        6
# 4                  18.0  0.99620  3.20       1.13     12.0        7

# %% [markdown]
# ### Data Pushed to MongoDb
