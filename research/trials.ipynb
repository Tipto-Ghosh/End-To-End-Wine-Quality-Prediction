# %% [markdown]
# ## Testing the ConfigBox and common.py methods

# %%
import yaml

yaml_file_path = "test.yaml"

# open the file and load it's contents as dictoinary
with open(yaml_file_path , 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'name': 'tipto', 'email': 'tiptoghosh@gmail.com'}

# %%
# Normal method to get dictionary values
data['name']
# Out:
# 'tipto'

# %%
data.email
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.email
#
# AttributeError: 'dict' object has no attribute 'email'

# %% [markdown]
# ## Access dictionary value using Congig Box

# %%
from box import ConfigBox 

new_data = ConfigBox(data)

# %%
print(type(new_data))
# Out:
# <class 'box.config_box.ConfigBox'>

# %%
new_data
# Out:
# ConfigBox({'name': 'tipto', 'email': 'tiptoghosh@gmail.com'})

# %%
new_data.name
# Out:
# 'tipto'
